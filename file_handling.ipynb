# %%
f = open("example.txt", "r") 
content = f.read() 
print(content)
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = open("example.txt", "r")
#       2 content = f.read()
#       3 print(content)
#       4 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'

# %%
f = open("example.txt", "w") 
f.write("Hello Adhil, File Handling!")
f.close()

# %%
f = open("example1.txt", "a") 
f.write("\nThis is an additional line.")
f.close()

# %%
try:
 num = int("abc")

except ValueError:
 print("Invalid input! Please enter a number.")
else:
 print("No Error")
# Out:
# Invalid input! Please enter a number.

# %%
try:
 result = int("100a")
 #result = 10 / 0

except ZeroDivisionError:
 print("Division by zero is not allowed.")
except Exception as e:
 print(f"An unexpected error occurred: {e}")
# Out:
# An unexpected error occurred: invalid literal for int() with base 10: '100a'

# %%
age = -25
assert age > 0, "x must be positive"
assert age < 0, "x must be negative"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 age = -25
# ----> 2 assert age > 0, "x must be positive"
#       3 assert age < 0, "x must be negative"
#
# AssertionError: x must be positive

# %%
try:
 file = open("sample.txt", "w")
 file.write("Hello")
 #print(1 / 0) # Will raise ZeroDivisionError
except ZeroDivisionError:
 print("Cannot divide by zero.")
else:
 print("No Error")
finally:
 file.close()
 print("File closed.")
# Out:
# No Error
# File closed.

# %%
try:
 num = int(input("Enter a number: "))
 assert num != 0, "Number cannot be zero."
 result = 10 / num
except ValueError:
 print("Please enter a valid integer.")
except AssertionError as e:
  print(e)
except ZeroDivisionError:
 print("Division by zero is not allowed.")
finally:
 print("Execution completed.")
# Out:
# Execution completed.
